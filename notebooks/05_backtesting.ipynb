# %% [markdown]
# # Backtesting
#
# Goal: Simulate strategy performance with realistic costs.
#
# Dataset: Signals, regimes, and historical prices.
#
# Expected Output: Performance metrics and trade logs.
