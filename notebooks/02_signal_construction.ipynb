# %% [markdown]
# # Signal Construction
#
# Goal: Generate trend-following and momentum signals.
#
# Dataset: Cleaned futures price data.
#
# Expected Output: Normalized trend signals ready for regime adjustment.
