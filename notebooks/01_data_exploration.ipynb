# %% [markdown]
# # Data Exploration
#
# Goal: Download, clean, and explore commodity futures data.
#
# Dataset: Continuous futures contracts for energy, metals, and agriculture.
#
# Expected Output: Cleaned, validated dataset ready for signal construction.
