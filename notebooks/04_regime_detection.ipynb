# %% [markdown]
# # Regime Detection
#
# Goal: Classify volatility regimes using Hidden Markov Models.
#
# Dataset: Volatility estimates and returns.
#
# Expected Output: Regime labels and transition probabilities.
