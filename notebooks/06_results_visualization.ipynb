# %% [markdown]
# # Results Visualization
#
# Goal: Generate performance reports and visualizations.
#
# Dataset: Backtest results and regime classifications.
#
# Expected Output: Figures, tables, and summary reports.
